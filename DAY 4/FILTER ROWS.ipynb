# %%
# to filter rows and access specific coulmns to perfom operations:--
''' when we access one column at a time :-- it will give series
when we access multiple columns:-- it return dataframe'''
# Out:
# ' when we access one column at a time :-- it will give series\nwhen we access multiple columns:-- it return dataframe'

# %%
import pandas as pd
d1={"name":["Yash","omkar","om","shivam","yogesh"],
    "age":[21,22,23,24,25],
    "salary":[100000000,200000,30000,40000,90000]}
df=pd.DataFrame(d1)

print("selecting specific columns:--")
column=df[["salary"]]
print(column)

print("selecting multiple columns:--")
columns=df[["salary","age"]]
print(columns)
# Out:
# selecting specific columns:--
#       salary
# 0  100000000
# 1     200000
# 2      30000
# 3      40000
# 4      90000
# selecting multiple columns:--
#       salary  age
# 0  100000000   21
# 1     200000   22
# 2      30000   23
# 3      40000   24
# 4      90000   25
