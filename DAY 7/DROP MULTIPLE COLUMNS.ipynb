# %%
# to remove multiple columns:--d1.drop(columns=[c1,c2])

# %%
import pandas as pd
d1=pd.DataFrame({"name":["YAsh","ashish","om","avi","prath"],
                 "salary":[100000,80000,50000,60000,30000],
                 "performance":[100,90,20,30,40],
                 "age":[24,20,30,40,38]})
print(d1)

d2=d1.drop(columns=["age","performance"])
print("dropped:--\n",d2)
# Out:
#      name  salary  performance  age
# 0    YAsh  100000          100   24
# 1  ashish   80000           90   20
# 2      om   50000           20   30
# 3     avi   60000           30   40
# 4   prath   30000           40   38
# dropped:--
#       name  salary
# 0    YAsh  100000
# 1  ashish   80000
# 2      om   50000
# 3     avi   60000
# 4   prath   30000
